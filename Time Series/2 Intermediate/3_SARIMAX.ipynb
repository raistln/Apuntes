# %% [markdown]
# # **Seasonal Auto-Regressive Integrated Moving Average with eXogenous factors (SARIMAX)**

# %%
# !python -m pip install pip --upgrade --user -q --no-warn-script-location
# !python -m pip install numpy pandas seaborn matplotlib scipy statsmodels sklearn tensorflow keras torch torchvision \
    tqdm scikit-image pmdarima --user -q --no-warn-script-location

import IPython
IPython.Application.instance().kernel.do_shutdown(True)

# %%
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
from pmdarima import auto_arima
from sklearn import metrics
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

warnings.filterwarnings("ignore")

# %%
# !gdown https://drive.google.com/uc?id=1E2QGmA4o4qTl59BNUjuzOJodR4nb_Gxb
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1E2QGmA4o4qTl59BNUjuzOJodR4nb_Gxb
# To: /content/FB.csv
# 100% 93.2k/93.2k [00:00<00:00, 35.7MB/s]

# %%
df = pd.read_csv(r'FB.csv')

# %%
df.head(10)
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2014-12-08  76.180000  77.250000  75.400002  76.519997  76.519997  25733900
# 1  2014-12-09  75.199997  76.930000  74.779999  76.839996  76.839996  25358600
# 2  2014-12-10  76.650002  77.550003  76.070000  76.180000  76.180000  32210500
# 3  2014-12-11  76.519997  78.519997  76.480003  77.730003  77.730003  33462100
# 4  2014-12-12  77.160004  78.879997  77.019997  77.830002  77.830002  28091600
# 5  2014-12-15  78.459999  78.580002  76.559998  76.989998  76.989998  29396500
# 6  2014-12-16  76.190002  77.389999  74.589996  74.690002  74.690002  31554600
# 7  2014-12-17  75.010002  76.410004  74.900002  76.110001  76.110001  29203900
# 8  2014-12-18  76.889999  78.400002  76.510002  78.400002  78.400002  34222100
# 9  2014-12-19  78.750000  80.000000  78.330002  79.879997  79.879997  43335000

# %%
def timeseries_evaluation_metrics_func(y_true, y_pred):
    
    def mean_absolute_percentage_error(y_true, y_pred): 
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    print('Evaluation metric results:-')
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
    print(f'MSE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')
    print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')

# %%
def Augmented_Dickey_Fuller_Test_func(series , column_name):
    print (f'Results of Dickey-Fuller Test for column: {column_name}')
    dftest = adfuller(series, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','No Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
       dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)
    if dftest[1] <= 0.05:
        print("Conclusion:====>")
        print("Reject the null hypothesis")
        print("Data is stationary")
    else:
        print("Conclusion:====>")
        print("Fail to reject the null hypothesis")
        print("Data is non-stationary")

# %%
for name, column in df[['Close' ,'Open' ,'High','Low']].iteritems():
    Augmented_Dickey_Fuller_Test_func(df[name],name)
    print('\n')
# Out:
# Results of Dickey-Fuller Test for column: Close
# Test Statistic                   -1.338096
# p-value                           0.611568
# No Lags Used                      0.000000
# Number of Observations Used    1258.000000
# Critical Value (1%)              -3.435559
# Critical Value (5%)              -2.863840
# Critical Value (10%)             -2.567995
# dtype: float64
# Conclusion:====>
# Fail to reject the null hypothesis
# Data is non-stationary
#
#
# Results of Dickey-Fuller Test for column: Open
# Test Statistic                   -1.014123
# p-value                           0.748078
# No Lags Used                     11.000000
# Number of Observations Used    1247.000000
# Critical Value (1%)              -3.435605
# Critical Value (5%)              -2.863861
# Critical Value (10%)             -2.568005
# dtype: float64
# Conclusion:====>
# Fail to reject the null hypothesis
# Data is non-stationary
#
#
# Results of Dickey-Fuller Test for column: High
# Test Statistic                   -1.255326
# p-value                           0.649355
# No Lags Used                      0.000000
# Number of Observations Used    1258.000000
# Critical Value (1%)              -3.435559
# Critical Value (5%)              -2.863840
# Critical Value (10%)             -2.567995
# dtype: float64
# Conclusion:====>
# Fail to reject the null hypothesis
# Data is non-stationary
#
#
# Results of Dickey-Fuller Test for column: Low
# Test Statistic                   -1.006754
# p-value                           0.750793
# No Lags Used                     10.000000
# Number of Observations Used    1248.000000
# Critical Value (1%)              -3.435601
# Critical Value (5%)              -2.863859
# Critical Value (10%)             -2.568004
# dtype: float64
# Conclusion:====>
# Fail to reject the null hypothesis
# Data is non-stationary

# %%
X = df[['Close' ]]
actualtrain, actualtest = X[0:-30], X[-30:]
exoX = df[['Open' ]]
exotrain, exotest = exoX[0:-30], exoX[-30:]

# %%
for m in [1, 4,7,12,52]:
    print("="*100)
    print(f' Fitting SARIMAX for Seasonal value m = {str(m)}')
    stepwise_model = auto_arima(actualtrain,exogenous =exotrain ,start_p=1, start_q=1,
    max_p=7, max_q=7, seasonal=True,start_P=1,start_Q=1,max_P=7,max_D=7,max_Q=7,m=m,
    d=None,D=None, trace=True,error_action='ignore',suppress_warnings=True, stepwise=True)


    print(f'Model summary for  m = {str(m)}')
    print("-"*100)
    stepwise_model.summary()

    forecast,conf_int = stepwise_model.predict(n_periods=30,exogenous =exotest,return_conf_int=True)
    df_conf = pd.DataFrame(conf_int,columns= ['Upper_bound','Lower_bound'])
    df_conf["new_index"] = range(1229, 1259)
    df_conf = df_conf.set_index("new_index")
    forecast = pd.DataFrame(forecast, columns=['close_pred'])
    forecast["new_index"] = range(1229, 1259)
    forecast = forecast.set_index("new_index")

    timeseries_evaluation_metrics_func(actualtest, forecast)

    import matplotlib.pyplot as plt
    # %matplotlib inline
    plt.rcParams["figure.figsize"] = [15, 7]
    plt.plot(actualtrain, label='Train ')
    plt.plot(actualtest, label='Test ')
    plt.plot(forecast, label=f'Predicted with m={str(m)} ')
    plt.plot(df_conf['Upper_bound'], label='Confidence Interval Upper bound ')
    plt.plot(df_conf['Lower_bound'], label='Confidence Interval Lower bound ')
    plt.legend(loc='best')
    plt.show()
    print("-"*100)
    print(f' Diagnostic plot for Seasonal value m = {str(m)}')
    
    display(stepwise_model.plot_diagnostics());
    print("-"*100)
# Out:
# ====================================================================================================
#  Fitting SARIMAX for Seasonal value m = 1
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=5155.727, Time=1.62 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=5178.246, Time=0.32 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=5157.564, Time=0.24 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=5155.602, Time=0.55 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=5176.629, Time=0.37 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=5156.191, Time=0.70 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=2.40 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=5153.614, Time=0.58 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=5153.760, Time=1.51 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=5154.202, Time=0.79 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=5155.603, Time=0.13 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=1.96 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0]
# Total fit time: 11.202 seconds
# Model summary for  m = 1
# ----------------------------------------------------------------------------------------------------
# Evaluation metric results:-
# MSE is : 3.5309682051767073
# MSE is : 1.4507246447030382
# RMSE is : 1.8790870669494555
# MAPE is : 0.7469662735339754
# R2 is : 0.8070803486577904
# ----------------------------------------------------------------------------------------------------
#  Diagnostic plot for Seasonal value m = 1
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
#  Fitting SARIMAX for Seasonal value m = 4
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(1,0,1)[4] intercept   : AIC=5158.880, Time=2.84 sec
#  ARIMA(0,0,0)(0,0,0)[4] intercept   : AIC=5178.246, Time=0.33 sec
#  ARIMA(1,0,0)(1,0,0)[4] intercept   : AIC=5159.298, Time=1.72 sec
#  ARIMA(0,0,1)(0,0,1)[4] intercept   : AIC=5157.178, Time=1.12 sec
#  ARIMA(0,0,0)(0,0,0)[4]             : AIC=5176.629, Time=0.38 sec
#  ARIMA(0,0,1)(0,0,0)[4] intercept   : AIC=5155.602, Time=0.56 sec
#  ARIMA(0,0,1)(1,0,0)[4] intercept   : AIC=5157.322, Time=1.72 sec
#  ARIMA(0,0,1)(1,0,1)[4] intercept   : AIC=5158.636, Time=0.41 sec
#  ARIMA(1,0,1)(0,0,0)[4] intercept   : AIC=5155.727, Time=1.50 sec
#  ARIMA(0,0,2)(0,0,0)[4] intercept   : AIC=5156.191, Time=0.65 sec
#  ARIMA(1,0,0)(0,0,0)[4] intercept   : AIC=5157.564, Time=0.30 sec
#  ARIMA(1,0,2)(0,0,0)[4] intercept   : AIC=inf, Time=2.39 sec
#  ARIMA(0,0,1)(0,0,0)[4]             : AIC=5153.614, Time=0.61 sec
#  ARIMA(0,0,1)(1,0,0)[4]             : AIC=5155.189, Time=0.64 sec
#  ARIMA(0,0,1)(0,0,1)[4]             : AIC=5155.159, Time=1.21 sec
#  ARIMA(0,0,1)(1,0,1)[4]             : AIC=5156.354, Time=1.28 sec
#  ARIMA(1,0,1)(0,0,0)[4]             : AIC=5153.760, Time=1.54 sec
#  ARIMA(0,0,2)(0,0,0)[4]             : AIC=5154.202, Time=0.79 sec
#  ARIMA(1,0,0)(0,0,0)[4]             : AIC=5155.603, Time=0.12 sec
#  ARIMA(1,0,2)(0,0,0)[4]             : AIC=inf, Time=2.01 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[4]
# Total fit time: 22.197 seconds
# Model summary for  m = 4
# ----------------------------------------------------------------------------------------------------
# Evaluation metric results:-
# MSE is : 3.5309682051767073
# MSE is : 1.4507246447030382
# RMSE is : 1.8790870669494555
# MAPE is : 0.7469662735339754
# R2 is : 0.8070803486577904
# ----------------------------------------------------------------------------------------------------
#  Diagnostic plot for Seasonal value m = 4
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
#  Fitting SARIMAX for Seasonal value m = 7
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(1,0,1)[7] intercept   : AIC=5159.442, Time=3.76 sec
#  ARIMA(0,0,0)(0,0,0)[7] intercept   : AIC=5178.246, Time=0.33 sec
#  ARIMA(1,0,0)(1,0,0)[7] intercept   : AIC=5158.762, Time=2.74 sec
#  ARIMA(0,0,1)(0,0,1)[7] intercept   : AIC=5157.057, Time=1.05 sec
#  ARIMA(0,0,0)(0,0,0)[7]             : AIC=5176.629, Time=0.39 sec
#  ARIMA(0,0,1)(0,0,0)[7] intercept   : AIC=5155.602, Time=0.56 sec
#  ARIMA(0,0,1)(1,0,0)[7] intercept   : AIC=5157.097, Time=2.08 sec
#  ARIMA(0,0,1)(1,0,1)[7] intercept   : AIC=5159.158, Time=1.22 sec
#  ARIMA(1,0,1)(0,0,0)[7] intercept   : AIC=5155.727, Time=1.50 sec
#  ARIMA(0,0,2)(0,0,0)[7] intercept   : AIC=5156.191, Time=0.68 sec
#  ARIMA(1,0,0)(0,0,0)[7] intercept   : AIC=5157.564, Time=0.31 sec
#  ARIMA(1,0,2)(0,0,0)[7] intercept   : AIC=inf, Time=2.41 sec
#  ARIMA(0,0,1)(0,0,0)[7]             : AIC=5153.614, Time=0.58 sec
#  ARIMA(0,0,1)(1,0,0)[7]             : AIC=5155.112, Time=1.26 sec
#  ARIMA(0,0,1)(0,0,1)[7]             : AIC=5155.104, Time=1.76 sec
#  ARIMA(0,0,1)(1,0,1)[7]             : AIC=5157.227, Time=2.10 sec
#  ARIMA(1,0,1)(0,0,0)[7]             : AIC=5153.760, Time=1.53 sec
#  ARIMA(0,0,2)(0,0,0)[7]             : AIC=5154.202, Time=0.78 sec
#  ARIMA(1,0,0)(0,0,0)[7]             : AIC=5155.603, Time=0.12 sec
#  ARIMA(1,0,2)(0,0,0)[7]             : AIC=inf, Time=1.97 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[7]
# Total fit time: 27.194 seconds
# Model summary for  m = 7
# ----------------------------------------------------------------------------------------------------
# Evaluation metric results:-
# MSE is : 3.5309682051767073
# MSE is : 1.4507246447030382
# RMSE is : 1.8790870669494555
# MAPE is : 0.7469662735339754
# R2 is : 0.8070803486577904
# ----------------------------------------------------------------------------------------------------
#  Diagnostic plot for Seasonal value m = 7
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
#  Fitting SARIMAX for Seasonal value m = 12
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(1,0,1)[12] intercept   : AIC=5158.566, Time=5.71 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=5178.246, Time=0.32 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=5158.340, Time=1.69 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=5156.426, Time=2.18 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=5176.629, Time=0.35 sec
#  ARIMA(0,0,1)(0,0,0)[12] intercept   : AIC=5155.602, Time=0.57 sec
#  ARIMA(0,0,1)(1,0,0)[12] intercept   : AIC=5156.262, Time=6.18 sec
#  ARIMA(0,0,1)(1,0,1)[12] intercept   : AIC=5158.620, Time=5.00 sec
#  ARIMA(1,0,1)(0,0,0)[12] intercept   : AIC=5155.727, Time=1.50 sec
#  ARIMA(0,0,2)(0,0,0)[12] intercept   : AIC=5156.191, Time=0.69 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=5157.564, Time=0.31 sec
#  ARIMA(1,0,2)(0,0,0)[12] intercept   : AIC=inf, Time=2.43 sec
#  ARIMA(0,0,1)(0,0,0)[12]             : AIC=5153.614, Time=0.61 sec
#  ARIMA(0,0,1)(1,0,0)[12]             : AIC=5154.396, Time=1.67 sec
#  ARIMA(0,0,1)(0,0,1)[12]             : AIC=5154.382, Time=2.78 sec
#  ARIMA(0,0,1)(1,0,1)[12]             : AIC=5156.633, Time=3.20 sec
#  ARIMA(1,0,1)(0,0,0)[12]             : AIC=5153.760, Time=1.54 sec
#  ARIMA(0,0,2)(0,0,0)[12]             : AIC=5154.202, Time=0.78 sec
#  ARIMA(1,0,0)(0,0,0)[12]             : AIC=5155.603, Time=0.12 sec
#  ARIMA(1,0,2)(0,0,0)[12]             : AIC=inf, Time=1.98 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[12]
# Total fit time: 39.682 seconds
# Model summary for  m = 12
# ----------------------------------------------------------------------------------------------------
# Evaluation metric results:-
# MSE is : 3.5309682051767073
# MSE is : 1.4507246447030382
# RMSE is : 1.8790870669494555
# MAPE is : 0.7469662735339754
# R2 is : 0.8070803486577904
# ----------------------------------------------------------------------------------------------------
#  Diagnostic plot for Seasonal value m = 12
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
#  Fitting SARIMAX for Seasonal value m = 52
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(1,0,1)[52] intercept   : AIC=5159.726, Time=34.68 sec
#  ARIMA(0,0,0)(0,0,0)[52] intercept   : AIC=5178.246, Time=0.34 sec
#  ARIMA(1,0,0)(1,0,0)[52] intercept   : AIC=5159.372, Time=47.79 sec
#  ARIMA(0,0,1)(0,0,1)[52] intercept   : AIC=5157.610, Time=8.24 sec
#  ARIMA(0,0,0)(0,0,0)[52]             : AIC=5176.629, Time=0.36 sec
#  ARIMA(0,0,1)(0,0,0)[52] intercept   : AIC=5155.602, Time=0.57 sec
#  ARIMA(0,0,1)(1,0,0)[52] intercept   : AIC=5157.586, Time=44.19 sec
#  ARIMA(0,0,1)(1,0,1)[52] intercept   : AIC=5159.551, Time=35.42 sec
#  ARIMA(1,0,1)(0,0,0)[52] intercept   : AIC=5155.727, Time=1.53 sec
#  ARIMA(0,0,2)(0,0,0)[52] intercept   : AIC=5156.191, Time=0.67 sec
#  ARIMA(1,0,0)(0,0,0)[52] intercept   : AIC=5157.564, Time=0.30 sec
#  ARIMA(1,0,2)(0,0,0)[52] intercept   : AIC=inf, Time=2.37 sec
#  ARIMA(0,0,1)(0,0,0)[52]             : AIC=5153.614, Time=0.57 sec
#  ARIMA(0,0,1)(1,0,0)[52]             : AIC=5155.596, Time=24.85 sec
#  ARIMA(0,0,1)(0,0,1)[52]             : AIC=5155.596, Time=20.04 sec
#  ARIMA(0,0,1)(1,0,1)[52]             : AIC=5157.596, Time=17.71 sec
#  ARIMA(1,0,1)(0,0,0)[52]             : AIC=5153.760, Time=1.54 sec
#  ARIMA(0,0,2)(0,0,0)[52]             : AIC=5154.202, Time=0.80 sec
#  ARIMA(1,0,0)(0,0,0)[52]             : AIC=5155.603, Time=0.12 sec
#  ARIMA(1,0,2)(0,0,0)[52]             : AIC=inf, Time=1.98 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[52]
# Total fit time: 244.167 seconds
# Model summary for  m = 52
# ----------------------------------------------------------------------------------------------------
# Evaluation metric results:-
# MSE is : 3.5309682051767073
# MSE is : 1.4507246447030382
# RMSE is : 1.8790870669494555
# MAPE is : 0.7469662735339754
# R2 is : 0.8070803486577904
# ----------------------------------------------------------------------------------------------------
#  Diagnostic plot for Seasonal value m = 52
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #**Related Articles:**
#
# > * [Date Time Parsing with Pandas](https://analyticsindiamag.com/datetime-parsing-with-pandas/)
